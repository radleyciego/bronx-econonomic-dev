# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2 
import io

# %%
public_150k_plus = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/0187d0dd-1a59-4c99-a04d-982231e68778/download/public_150k_plus_220930.csv')
public_150k_plus
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       9547507704   05/01/2020            464              PPP
# 1       9777677704   05/01/2020            464              PPP
# 2       5791407702   05/01/2020           1013              PPP
# 3       6223567700   05/01/2020            920              PPP
# 4       9662437702   05/01/2020            101              PPP
# ...            ...          ...            ...              ...
# 968526  4395967002   04/03/2020            897              PPP
# 968527  6985647108   04/14/2020            897              PPP
# 968528  7996438405   02/12/2021            897              PPS
# 968529  9054647103   04/15/2020            897              PPP
# 968530  9184687004   04/09/2020            897              PPP
#
#                                              BorrowerName  \
# 0                                   SUMTER COATINGS, INC.
# 1                                   PLEASANT PLACES, INC.
# ...

# %%
public_150k_plus = public_150k_plus.rename(columns=str.lower)
public_150k_plus
# Out:
#         loannumber dateapproved  sbaofficecode processingmethod  \
# 0       9547507704   05/01/2020            464              PPP
# 1       9777677704   05/01/2020            464              PPP
# 2       5791407702   05/01/2020           1013              PPP
# 3       6223567700   05/01/2020            920              PPP
# 4       9662437702   05/01/2020            101              PPP
# ...            ...          ...            ...              ...
# 968526  4395967002   04/03/2020            897              PPP
# 968527  6985647108   04/14/2020            897              PPP
# 968528  7996438405   02/12/2021            897              PPS
# 968529  9054647103   04/15/2020            897              PPP
# 968530  9184687004   04/09/2020            897              PPP
#
#                                              borrowername  \
# 0                                   SUMTER COATINGS, INC.
# 1                                   PLEASANT PLACES, INC.
# ...

# %%
public_150k_1 = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/ef9a027d-6681-4e36-a1d8-82757dd210b4/download/public_up_to_150k_1_220930.csv')
public_150k_1
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       3509338307   01/22/2021            NaN              PPS
# 1       5375617707   05/01/2020          101.0              PPP
# 2       9677497701   05/01/2020          464.0              PPP
# 3       9547167709   05/01/2020          464.0              PPP
# 4       8885207205   04/28/2020            NaN              PPP
# ...            ...          ...            ...              ...
# 899995  6736609000   05/23/2021          912.0              PPS
# 899996  6736679010   05/23/2021          931.0              PPP
# 899997  6736718601   03/23/2021          914.0              PPP
# 899998  6736819004   05/23/2021          914.0              PPS
# 899999  6736908904   05/02/2021          912.0              PPS
#
#                                   BorrowerName          BorrowerAddress  \
# 0                                  Exemption 6                      NaN
# ...

# %%
public_150k_1 = public_150k_1.rename(columns=str.lower)
public_150k_1
# Out:
#         loannumber dateapproved  sbaofficecode processingmethod  \
# 0       3509338307   01/22/2021            NaN              PPS
# 1       5375617707   05/01/2020          101.0              PPP
# 2       9677497701   05/01/2020          464.0              PPP
# 3       9547167709   05/01/2020          464.0              PPP
# 4       8885207205   04/28/2020            NaN              PPP
# ...            ...          ...            ...              ...
# 899995  6736609000   05/23/2021          912.0              PPS
# 899996  6736679010   05/23/2021          931.0              PPP
# 899997  6736718601   03/23/2021          914.0              PPP
# 899998  6736819004   05/23/2021          914.0              PPS
# 899999  6736908904   05/02/2021          912.0              PPS
#
#                                   borrowername          borroweraddress  \
# 0                                  Exemption 6                      NaN
# ...

# %%
public_150k_2 = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/cd9ec3d9-515a-4064-b843-2c22ad9046b4/download/public_up_to_150k_2_220930.csv')
public_150k_2
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       6737108107   07/22/2020            920              PPP
# 1       6737598604   03/23/2021            914              PPP
# 2       6737708709   04/04/2021            914              PPP
# 3       6737708905   05/02/2021            914              PPP
# 4       6737768803   04/20/2021            920              PPP
# ...            ...          ...            ...              ...
# 899995  3308128405   02/04/2021            156              PPP
# 899996  3016849000   05/18/2021            156              PPP
# 899997  1400518408   02/01/2021            156              PPS
# 899998  6064368610   03/20/2021            156              PPS
# 899999  9796187204   04/28/2020            156              PPP
#
#                                BorrowerName          BorrowerAddress  \
# 0                                    XI LUO    10670 ORCHARD VIEW LN
# ...

# %%
public_150k_2 = public_150k_2.rename(columns=str.lower)
public_150k_2
# Out:
#         loannumber dateapproved  sbaofficecode processingmethod  \
# 0       6737108107   07/22/2020            920              PPP
# 1       6737598604   03/23/2021            914              PPP
# 2       6737708709   04/04/2021            914              PPP
# 3       6737708905   05/02/2021            914              PPP
# 4       6737768803   04/20/2021            920              PPP
# ...            ...          ...            ...              ...
# 899995  3308128405   02/04/2021            156              PPP
# 899996  3016849000   05/18/2021            156              PPP
# 899997  1400518408   02/01/2021            156              PPS
# 899998  6064368610   03/20/2021            156              PPS
# 899999  9796187204   04/28/2020            156              PPP
#
#                                borrowername          borroweraddress  \
# 0                                    XI LUO    10670 ORCHARD VIEW LN
# ...

# %%
public_150k_3 = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/5fbc42c5-12fc-4c8d-a515-17c5a2a576fb/download/public_up_to_150k_3_220930.csv')
public_150k_3
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       1143907409   05/04/2020            156              PPP
# 1       5842618605   03/20/2021            156              PPP
# 2       3284178109   07/14/2020            156              PPP
# 3       4167858902   04/28/2021            156              PPP
# 4       5343878804   04/17/2021            156              PPP
# ...            ...          ...            ...              ...
# 899995  6482757409   05/14/2020            455              PPP
# 899996  6487677103   04/14/2020            455              PPP
# 899997  6643377905   06/16/2020            455              PPP
# 899998  6684338700   04/04/2021            455              PPS
# 899999  6693197810   06/02/2020            455              PPP
#
#                          BorrowerName          BorrowerAddress   BorrowerCity  \
# 0                    SIGHT SPECS, LLC             17 S MAIN ST  WEST HARTFORD
# ...

# %%
public_150k_3 = public_150k_3.rename(columns=str.lower)
public_150k_3
# Out:
#         loannumber dateapproved  sbaofficecode processingmethod  \
# 0       1143907409   05/04/2020            156              PPP
# 1       5842618605   03/20/2021            156              PPP
# 2       3284178109   07/14/2020            156              PPP
# 3       4167858902   04/28/2021            156              PPP
# 4       5343878804   04/17/2021            156              PPP
# ...            ...          ...            ...              ...
# 899995  6482757409   05/14/2020            455              PPP
# 899996  6487677103   04/14/2020            455              PPP
# 899997  6643377905   06/16/2020            455              PPP
# 899998  6684338700   04/04/2021            455              PPS
# 899999  6693197810   06/02/2020            455              PPP
#
#                          borrowername          borroweraddress   borrowercity  \
# 0                    SIGHT SPECS, LLC             17 S MAIN ST  WEST HARTFORD
# ...

# %%
public_150k_4 = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/10ae13df-9445-4dd1-98ca-4efa925573c1/download/public_up_to_150k_4_220930.csv')
public_150k_4
# Out:
# /var/folders/ff/9n9lg70d5d79jcc1pfmzhbsc0000gn/T/ipykernel_7443/1069842104.py:1: DtypeWarning: Columns (50) have mixed types. Specify dtype option on import or set low_memory=False.
#   public_150k_4 = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/10ae13df-9445-4dd1-98ca-4efa925573c1/download/public_up_to_150k_4_220930.csv')
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       6696008409   02/10/2021            455              PPP
# 1       6755328009   06/30/2020            455              PPP
# 2       6805948409   02/11/2021            491              PPS
# 3       6816517800   06/02/2020            455              PPP
# 4       6820087304   04/30/2020            455              PPP
# ...            ...          ...            ...              ...
# 899995  8262587109   04/15/2020           1087              PPP
# 899996  8938307205   04/28/2020           1087              PPP
# ...

# %%
public_150k_4 = public_150k_4.rename(columns=str.lower)
public_150k_4
# Out:
#         loannumber dateapproved  sbaofficecode processingmethod  \
# 0       6696008409   02/10/2021            455              PPP
# 1       6755328009   06/30/2020            455              PPP
# 2       6805948409   02/11/2021            491              PPS
# 3       6816517800   06/02/2020            455              PPP
# 4       6820087304   04/30/2020            455              PPP
# ...            ...          ...            ...              ...
# 899995  8262587109   04/15/2020           1087              PPP
# 899996  8938307205   04/28/2020           1087              PPP
# 899997  8983697303   05/01/2020           1087              PPP
# 899998  9048607008   04/09/2020           1094              PPP
# 899999  9432917110   04/15/2020           1094              PPP
#
#                                        borrowername  \
# 0                                 MARLENE BAHARALLY
# 1                                 KAREN K. PFLIEGER
# ...

# %%
public_150k_5 = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/0179d099-67c6-4cf1-89ac-df0f36481929/download/public_up_to_150k_5_220930.csv')
public_150k_5
# Out:
# /var/folders/ff/9n9lg70d5d79jcc1pfmzhbsc0000gn/T/ipykernel_7443/1190419873.py:1: DtypeWarning: Columns (16,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   public_150k_5 = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/0179d099-67c6-4cf1-89ac-df0f36481929/download/public_up_to_150k_5_220930.csv')
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       9480687303   05/02/2020           1087              PPP
# 1       1734398507   02/19/2021           1087              PPS
# 2       3502198604   03/17/2021           1087              PPS
# 3       8903298701   04/08/2021           1087              PPP
# 4       2941568801   04/13/2021           1087              PPP
# ...            ...          ...            ...              ...
# 899995  9458218509   03/12/2021            457              PPS
# 899996  7600047306   04/30/2020            457              PPP
# ...

# %%
public_150k_5 = public_150k_5.rename(columns=str.lower)
public_150k_5
# Out:
#         loannumber dateapproved  sbaofficecode processingmethod  \
# 0       9480687303   05/02/2020           1087              PPP
# 1       1734398507   02/19/2021           1087              PPS
# 2       3502198604   03/17/2021           1087              PPS
# 3       8903298701   04/08/2021           1087              PPP
# 4       2941568801   04/13/2021           1087              PPP
# ...            ...          ...            ...              ...
# 899995  9458218509   03/12/2021            457              PPS
# 899996  7600047306   04/30/2020            457              PPP
# 899997  1719787109   04/10/2020            457              PPP
# 899998  2402308402   02/03/2021            457              PPS
# 899999  3481568303   01/22/2021            457              PPS
#
#                                 borrowername           borroweraddress  \
# 0                  PROGRESS PATENT LAW, PLLC   1225 West Bacall Street
# ...

# %%
public_150k_6 = public_150k_6.rename(columns=str.lower)
public_150k_6
# Out:
#         loannumber dateapproved  sbaofficecode processingmethod  \
# 0       6682198005   06/30/2020            457              PPP
# 1       7739327007   04/08/2020            457              PPP
# 2       4777357307   04/30/2020            457              PPP
# 3       1854788402   02/02/2021            457              PPS
# 4       1162627207   04/15/2020            457              PPP
# ...            ...          ...            ...              ...
# 899995  2971648508   02/22/2021            515              PPS
# 899996  3117548704   03/30/2021            515              PPS
# 899997  3191768404   02/04/2021            515              PPP
# 899998  3254018607   03/16/2021            515              PPS
# 899999  3289727307   04/29/2020            515              PPP
#
#                                 borrowername               borroweraddress  \
# 0                    HAPPY TALK WIRELESS LLC               10108 Dixie Hwy
# ...

# %%
public_150k_7 = public_150k_7.rename(columns=str.lower)
public_150k_7
# Out:
#         loannumber dateapproved  sbaofficecode processingmethod  \
# 0       3393407305   04/29/2020            515              PPP
# 1       3457578306   01/22/2021            515              PPS
# 2       3536728606   03/17/2021            515              PPP
# 3       3630617303   04/29/2020            515              PPP
# 4       3675518700   03/31/2021            515              PPP
# ...            ...          ...            ...              ...
# 899995  4404468309   01/23/2021            875              PPS
# 899996  8847257001   04/08/2020            875              PPP
# 899997  2990888407   02/04/2021            875              PPP
# 899998  2699778806   04/13/2021            875              PPS
# 899999  1123498307   01/16/2021            875              PPS
#
#                                            borrowername  \
# 0                                     JOSLYN LIQUOR INC
# 1                                      ANGELS CARE INC.
# ...

# %%
public_150k_8 = public_150k_8.rename(columns=str.lower)
public_150k_8
# Out:
#         loannumber dateapproved  sbaofficecode processingmethod  \
# 0       8412007008   04/08/2020            875              PPP
# 1       8639698703   04/07/2021            875              PPS
# 2       6303808304   01/26/2021            875              PPS
# 3       2264578305   01/20/2021            875              PPS
# 4       1490707402   05/04/2020            875              PPP
# ...            ...          ...            ...              ...
# 899995  4950598201   08/07/2020            248              PPP
# 899996  4950637803   05/29/2020            202              PPP
# 899997  4951057307   04/30/2020            235              PPP
# 899998  4951548003   06/26/2020            248              PPP
# 899999  4953728209   08/07/2020            296              PPP
#
#                         borrowername              borroweraddress  \
# 0                   VAN HOOK TTI LLC              8226 39TH ST NW
# ...

# %%
public_150k_9 = public_150k_9.rename(columns=str.lower)
public_150k_9
# Out:
#         loannumber dateapproved  sbaofficecode processingmethod  \
# 0       4955687403   05/11/2020            248              PPP
# 1       4957007402   05/11/2020            248              PPP
# 2       4963257207   04/27/2020            296              PPP
# 3       4963457306   04/30/2020            202              PPP
# 4       4963819005   05/21/2021            202              PPP
# ...            ...          ...            ...              ...
# 899995  4103797401   05/08/2020           1086              PPP
# 899996  9861728302   01/31/2021           1086              PPS
# 899997  2085927301   04/29/2020           1086              PPP
# 899998  4918417110   04/13/2020           1086              PPP
# 899999  9793947310   05/02/2020           1086              PPP
#
#                       borrowername             borroweraddress   borrowercity  \
# 0                       PAUL ARENA           123 farwood drive  baldwinsville
# ...

# %%
public_150k_10 = public_150k_10.rename(columns=str.lower)
public_150k_10
# Out:
#         loannumber dateapproved  sbaofficecode processingmethod  \
# 0       3193678710   03/30/2021           1086              PPS
# 1       2130898508   02/19/2021           1086              PPP
# 2       5528428010   06/28/2020           1086              PPP
# 3       7945778402   02/12/2021           1086              PPP
# 4       7197178708   04/05/2021           1086              PPP
# ...            ...          ...            ...              ...
# 899995  1005898907   04/24/2021            610              PPS
# 899996  2899617704   05/01/2020            681              PPP
# 899997  3688698500   02/24/2021            639              PPS
# 899998  5305828407   02/08/2021            681              PPS
# 899999  3827098106   07/15/2020            678              PPP
#
#                                              borrowername  \
# 0                                CLASSIC BODY RESTORATION
# 1                                         KATHERIN MORRIS
# ...

# %%
public_150k_11 = public_150k_11.rename(columns=str.lower)
public_150k_11
# Out:
#         loannumber dateapproved  sbaofficecode processingmethod  \
# 0       7230607310   04/30/2020            639              PPP
# 1       6108028409   02/10/2021            681              PPS
# 2       5119038609   03/20/2021            681              PPS
# 3       9563238310   01/31/2021            671              PPS
# 4       9792098309   01/31/2021            671              PPS
# ...            ...          ...            ...              ...
# 899995  3374047102   04/11/2020            353              PPP
# 899996  3596768304   01/22/2021            304              PPS
# 899997  3634367210   04/27/2020            304              PPP
# 899998  3939128608   03/17/2021            304              PPS
# 899999  4546637703   05/01/2020            304              PPP
#
#                                              borrowername  \
# 0        ALL VALLEY REHABILITATION SPINE & PAIN INSTITUTE
# 1                            ROOF MAINTENANCE SYSTEMS LLC
# ...

# %%
public_150k_12 = public_150k_12.rename(columns=str.lower)
public_150k_12
# Out:
#         loannumber dateapproved  sbaofficecode processingmethod  \
# 0       4559397800   05/28/2020            353              PPP
# 1       4784467107   04/13/2020            304              PPP
# 2       4939997010   04/04/2020            353              PPP
# 3       5055638002   06/26/2020            353              PPP
# 4       5145117704   05/01/2020            353              PPP
# ...            ...          ...            ...              ...
# 599902  9160347307   05/01/2020            897              PPP
# 599903  8452318607   03/24/2021            897              PPP
# 599904  5991058901   05/01/2021            897              PPP
# 599905  6164058608   03/20/2021            897              PPP
# 599906  5170998610   03/20/2021            897              PPP
#
#                                        borrowername  \
# 0                  ARLINGTON CONSULTANTS GROUP, LLC
# 1       ELEVATING EQUIPMENT INSPECTION SERVICE, LLC
# ...

# %%
public_150k_6 = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/8f1f2f33-2741-40cb-ad2d-a9c6a1d3ab64/download/public_up_to_150k_6_220930.csv')
public_150k_6
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       6682198005   06/30/2020            457              PPP
# 1       7739327007   04/08/2020            457              PPP
# 2       4777357307   04/30/2020            457              PPP
# 3       1854788402   02/02/2021            457              PPS
# 4       1162627207   04/15/2020            457              PPP
# ...            ...          ...            ...              ...
# 899995  2971648508   02/22/2021            515              PPS
# 899996  3117548704   03/30/2021            515              PPS
# 899997  3191768404   02/04/2021            515              PPP
# 899998  3254018607   03/16/2021            515              PPS
# 899999  3289727307   04/29/2020            515              PPP
#
#                                 BorrowerName               BorrowerAddress  \
# 0                    HAPPY TALK WIRELESS LLC               10108 Dixie Hwy
# ...

# %%
public_150k_7 = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/4219ac7e-0c8b-44ba-a3da-b0219da2bdf0/download/public_up_to_150k_7_220930.csv')
public_150k_7
# Out:
# /var/folders/ff/9n9lg70d5d79jcc1pfmzhbsc0000gn/T/ipykernel_7443/2144867017.py:1: DtypeWarning: Columns (50) have mixed types. Specify dtype option on import or set low_memory=False.
#   public_150k_7 = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/4219ac7e-0c8b-44ba-a3da-b0219da2bdf0/download/public_up_to_150k_7_220930.csv')
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       3393407305   04/29/2020            515              PPP
# 1       3457578306   01/22/2021            515              PPS
# 2       3536728606   03/17/2021            515              PPP
# 3       3630617303   04/29/2020            515              PPP
# 4       3675518700   03/31/2021            515              PPP
# ...            ...          ...            ...              ...
# 899995  4404468309   01/23/2021            875              PPS
# 899996  8847257001   04/08/2020            875              PPP
# ...

# %%
public_150k_8 = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/72dc801a-83e0-4e2e-a59c-66437282b661/download/public_up_to_150k_8_220930.csv')
public_150k_8
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       8412007008   04/08/2020            875              PPP
# 1       8639698703   04/07/2021            875              PPS
# 2       6303808304   01/26/2021            875              PPS
# 3       2264578305   01/20/2021            875              PPS
# 4       1490707402   05/04/2020            875              PPP
# ...            ...          ...            ...              ...
# 899995  4950598201   08/07/2020            248              PPP
# 899996  4950637803   05/29/2020            202              PPP
# 899997  4951057307   04/30/2020            235              PPP
# 899998  4951548003   06/26/2020            248              PPP
# 899999  4953728209   08/07/2020            296              PPP
#
#                         BorrowerName              BorrowerAddress  \
# 0                   VAN HOOK TTI LLC              8226 39TH ST NW
# ...

# %%
public_150k_9 = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/b3e10cb1-ff86-4dc9-a2d8-28cfe8f100dd/download/public_up_to_150k_9_220930.csv')
public_150k_9
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       4955687403   05/11/2020            248              PPP
# 1       4957007402   05/11/2020            248              PPP
# 2       4963257207   04/27/2020            296              PPP
# 3       4963457306   04/30/2020            202              PPP
# 4       4963819005   05/21/2021            202              PPP
# ...            ...          ...            ...              ...
# 899995  4103797401   05/08/2020           1086              PPP
# 899996  9861728302   01/31/2021           1086              PPS
# 899997  2085927301   04/29/2020           1086              PPP
# 899998  4918417110   04/13/2020           1086              PPP
# 899999  9793947310   05/02/2020           1086              PPP
#
#                       BorrowerName             BorrowerAddress   BorrowerCity  \
# 0                       PAUL ARENA           123 farwood drive  baldwinsville
# ...

# %%
public_150k_10 = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/04f67234-e40c-4759-bbbe-fff96d814c53/download/public_up_to_150k_10_220930.csv')
public_150k_10
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       3193678710   03/30/2021           1086              PPS
# 1       2130898508   02/19/2021           1086              PPP
# 2       5528428010   06/28/2020           1086              PPP
# 3       7945778402   02/12/2021           1086              PPP
# 4       7197178708   04/05/2021           1086              PPP
# ...            ...          ...            ...              ...
# 899995  1005898907   04/24/2021            610              PPS
# 899996  2899617704   05/01/2020            681              PPP
# 899997  3688698500   02/24/2021            639              PPS
# 899998  5305828407   02/08/2021            681              PPS
# 899999  3827098106   07/15/2020            678              PPP
#
#                                              BorrowerName  \
# 0                                CLASSIC BODY RESTORATION
# 1                                         KATHERIN MORRIS
# ...

# %%
public_150k_11 = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/92a11063-e58e-4f45-a1ec-32821234b82b/download/public_up_to_150k_11_220930.csv')
public_150k_11
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       7230607310   04/30/2020            639              PPP
# 1       6108028409   02/10/2021            681              PPS
# 2       5119038609   03/20/2021            681              PPS
# 3       9563238310   01/31/2021            671              PPS
# 4       9792098309   01/31/2021            671              PPS
# ...            ...          ...            ...              ...
# 899995  3374047102   04/11/2020            353              PPP
# 899996  3596768304   01/22/2021            304              PPS
# 899997  3634367210   04/27/2020            304              PPP
# 899998  3939128608   03/17/2021            304              PPS
# 899999  4546637703   05/01/2020            304              PPP
#
#                                              BorrowerName  \
# 0        ALL VALLEY REHABILITATION SPINE & PAIN INSTITUTE
# 1                            ROOF MAINTENANCE SYSTEMS LLC
# ...

# %%
public_150k_12 = pd.read_csv('https://data.sba.gov/dataset/8aa276e2-6cab-4f86-aca4-a7dde42adf24/resource/6dd520ff-c211-404f-b7eb-29784cd4dbda/download/public_up_to_150k_12_220930.csv')
public_150k_12
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       4559397800   05/28/2020            353              PPP
# 1       4784467107   04/13/2020            304              PPP
# 2       4939997010   04/04/2020            353              PPP
# 3       5055638002   06/26/2020            353              PPP
# 4       5145117704   05/01/2020            353              PPP
# ...            ...          ...            ...              ...
# 599902  9160347307   05/01/2020            897              PPP
# 599903  8452318607   03/24/2021            897              PPP
# 599904  5991058901   05/01/2021            897              PPP
# 599905  6164058608   03/20/2021            897              PPP
# 599906  5170998610   03/20/2021            897              PPP
#
#                                        BorrowerName  \
# 0                  ARLINGTON CONSULTANTS GROUP, LLC
# 1       ELEVATING EQUIPMENT INSPECTION SERVICE, LLC
# ...

# %%
engine = create_engine('postgresql://radleyciego:Spot28@localhost:1841/bxbp')
public_150k_plus.to_sql('publix_150k_plus', engine)
# Out:
# 531

# %%
engine = create_engine('postgresql://radleyciego:Spot28@localhost:1841/bxbp')
public_150k_1.to_sql('public_150k_1', engine)
# Out:
# 1000

# %%
engine = create_engine('postgresql://radleyciego:Spot28@localhost:1841/bxbp')
public_150k_2.to_sql('public_150k_2', engine)
# Out:
# 1000

# %%
engine = create_engine('postgresql://radleyciego:Spot28@localhost:1841/bxbp')
public_150k_3.to_sql('public_150k_3', engine)
# Out:
# 1000

# %%
engine = create_engine('postgresql://radleyciego:Spot28@localhost:1841/bxbp')
public_150k_4.to_sql('public_150k_4', engine)
# Out:
# 1000

# %%
engine = create_engine('postgresql://radleyciego:Spot28@localhost:1841/bxbp')
public_150k_5.to_sql('public_150k_5', engine)
# Out:
# 1000

# %%
engine = create_engine('postgresql://radleyciego:Spot28@localhost:1841/bxbp')
public_150k_6.to_sql('public_150k_6', engine)
# Out:
# 1000

# %%
engine = create_engine('postgresql://radleyciego:Spot28@localhost:1841/bxbp')
public_150k_7.to_sql('public_150k_7', engine)
# Out:
# 1000

# %%
engine = create_engine('postgresql://radleyciego:Spot28@localhost:1841/bxbp')
public_150k_8.to_sql('public_150k_8', engine)
# Out:
# 1000

# %%
engine = create_engine('postgresql://radleyciego:Spot28@localhost:1841/bxbp')
public_150k_9.to_sql('public_150k_9', engine)
# Out:
# 1000

# %%
engine = create_engine('postgresql://radleyciego:Spot28@localhost:1841/bxbp')
public_150k_10.to_sql('public_150k_10', engine)
# Out:
# 1000

# %%
engine = create_engine('postgresql://radleyciego:Spot28@localhost:1841/bxbp')
public_150k_11.to_sql('public_150k_11', engine)
# Out:
# 1000

# %%
engine = create_engine('postgresql://radleyciego:Spot28@localhost:1841/bxbp')
public_150k_12.to_sql('public_150k_12', engine)
# Out:
# 907
